# %% [markdown]
# Pegar dados de IPCA:
#
# *   Mês e Ano ---------------- A3
# *   Índice Geral ------------- linha 07 col A (0) a M (12)
#
# *   Milho Verde em Conserva --
# *   Fubá de Milho ------------ linha 25
# *   Milho em Grão ------------ linha 19
# *   Milho Verde em Espiga ---- linha 20 ---- Não pegar
#
# *   Café Moído --------------- linha 213
# *   Café Solúvel ------------- linha 214
#
# *   Acúcar e derivados ------- linha 56
# *   Açúcar refinado ---------- linha 57
# *   Açúcar cristal ----------- linha 58
#
# *   Laranja-Pêra -------------
# *   Laranja Lima ------------- linha 97
# *   Laranja Seleta ----------- linha 98
# *   Laranja Baía ------------- linha 96
#
# *   Arroz -------------------- linha 12
# *   Tomate ------------------- linha 49
